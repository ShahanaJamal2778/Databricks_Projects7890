# %%
# %sql
SELECT * FROM workspace.sales_db.dim_customers

# %%
# python
from pyspark.sql import functions as F
df=spark.table("workspace.sales_db.dim_customers")
df.display()

# %%
# both sql and spark mix
df=spark.sql("""
              select * from workspace.sales_db.dim_customers""")
df.display()

# %%
# %sql DESCRIBE HISTORY workspace.sales_db.dim_customers

# %%
# %sql
SELECT * FROM workspace.sales_db.dim_customers VERSION AS OF 0
