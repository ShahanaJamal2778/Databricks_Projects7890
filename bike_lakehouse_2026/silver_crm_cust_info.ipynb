# %% [markdown]
# ## Reading From Bronze

# %%
df=spark.table("workspace.bronze.crm_cust_info")

# %% [markdown]
# ## Data Transformation

# %%
df.display()

# %% [markdown]
# ## Write Into Silver Table
