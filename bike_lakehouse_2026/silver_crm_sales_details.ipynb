# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StringType, DateType
from pyspark.sql.functions import col, trim, length

# %% [markdown]
# ## Read Bronze Table

# %%
df=spark.table("workspace.bronze.crm_sales_details")

# %%
df.display()

# %% [markdown]
# ## Check null

# %%
null_counts = df.select([F.count(F.when(col(c).isNull(), c)).alias(c) for c in df.columns])
display(null_counts)

# %% [markdown]
# ## Triming

# %%
for field in df.schema.fields:
    if isinstance(field.dataType, StringType):
        df = df.withColumn(field.name, trim(col(field.name)))

# %% [markdown]
# ## Cleaning Date

# %%
df=(
    df
    .withColumn("sls_ship_dt",F.when((col("sls_ship_dt")==0) | (col("sls_ship_dt")!=8),None).otherwise(
        F.to_date(col("sls_ship_dt").cast("string"),"yyyyMMdd")))
    .withColumn("sls_due_dt",F.when((col("sls_due_dt")==0) | (col("sls_due_dt")!=8),None).otherwise(
        F.to_date(col("sls_due_dt").cast("string"),"yyyyMMdd")))
    .withColumn("sls_order_dt",F.when(
        (col("sls_order_dt")==0) | (col("sls_order_dt")!=8),None
    ).otherwise(
        F.to_date(col("sls_order_dt").cast("string"),"yyyyMMdd")))
)

# %%
df = (
    df
    .withColumn(
        "sls_order_dt",
        F.when(
            (col("sls_order_dt") == 0) | (length(col("sls_order_dt")) != 8),
            None
        ).otherwise(F.to_date(col("sls_order_dt").cast("string"), "yyyyMMdd"))
    )
    .withColumn(
        "sls_ship_dt",
        F.when(
            (col("sls_ship_dt") == 0) | (length(col("sls_ship_dt")) != 8),
            None
        ).otherwise(F.to_date(col("sls_ship_dt").cast("string"), "yyyyMMdd"))
    )
    .withColumn(
        "sls_due_dt",
        F.when(
            (col("sls_due_dt") == 0) | (length(col("sls_due_dt")) != 8),
            None
        ).otherwise(F.to_date(col("sls_due_dt").cast("string"), "yyyyMMdd"))
    )
)

# %% [markdown]
# ## Sales And Price Correction

# %%
df.display()

# %%
df = (
    df
    .withColumn(
        "sls_price",
        F.when(
            (col("sls_price").isNull()) | (col("sls_price") <= 0),
            F.when(
                col("sls_quantity") != 0,
                col("sls_sales") / col("sls_quantity")
            ).otherwise(None)
        ).otherwise(col("sls_price"))
    )
)

# %%
import pyspark.pandas as ps

psdf = df.toPandas()
psdf["sls_order_dt"] = psdf["sls_order_dt"].ffill()
df = spark.createDataFrame(psdf)
display(df)

# %% [markdown]
# ## Renaming Columns

# %%
RENAME_MAP = {
    "sls_ord_num": "order_number",
    "sls_prd_key": "product_number",
    "sls_cust_id": "customer_id",
    "sls_order_dt": "order_date",
    "sls_ship_dt": "ship_date",
    "sls_due_dt": "due_date",
    "sls_sales": "sales_amount",
    "sls_quantity": "quantity",
    "sls_price": "price"
}
for old_name, new_name in RENAME_MAP.items():
    df = df.withColumnRenamed(old_name, new_name)

# %%
df.limit(10).display()

# %% [markdown]
# ## write to `bronze`

# %%
df.write.mode("overwrite").format("delta").saveAsTable("workspace.silver.crm_sales")

# %% [markdown]
# ## Check sanity

# %%
# %sql
SELECT * FROM workspace.silver.crm_sales LIMIT 10
